# %% [markdown]
# # T-norm operators

# %%
import numpy as np

import FuzzySystem as fs

# %% [markdown]
# ### Initial Fuzzy Set

# %%
mf = fs.FuzzySet('MF1', fs.Gaussmf([2,5], universe=[0,10]))
mf.show()

# %% [markdown]
# ### T-norm as the minimum

# %%
mf.cut(.7)
mf.fs_operator = 'min'
mf.show()

# %% [markdown]
# ### T-norm as the product

# %%
mf.cut(.7)
mf.fs_operator = 'prod'
mf.show()
