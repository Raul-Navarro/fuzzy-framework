# %%
import numpy as np

import FuzzySystem as fs

# %%
mf = fs.FuzzySet('MF1', fs.Gaussmf([2,5], universe=[0,10]))
mf.show()

# %%
mf.cut(.7)
mf.fs_operator = 'min'
mf.show()

# %%
mf.cut(.7)
mf.fs_operator = 'prod'
mf.show()
